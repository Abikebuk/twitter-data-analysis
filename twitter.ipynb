# %% [markdown]
# # Document to Graph database processing

# %% [markdown]
# This project processes data from twitter stream to a graph.
# The goal of this project is to analyze the interaction between people on Twitter by analyzing their discussion.
#
# This project takes data from a document MongoDB database and process it into a graph Neo4J database.
# Each nodes of the graph contains one user and each relation are one sided.
# There is only one type of relation : (user1) --- speaksOf ---> (user2)
# Each user has a weight which is the number of time one user spoke about him
# Each relation has a weight that represent how many time user1 spoke about user2

# %% [markdown]
# Imports pymongo and neo4j

# %%
import pymongo
from neo4j import GraphDatabase, AsyncGraphDatabase
import re

# %% [markdown]
# MongoDB configuration (change with your own config)

# %%
client = pymongo.MongoClient("mongodb://localhost:27017")

# %% [markdown]
# Neo4j configuration (change with your own config)

# %%
URI = "bolt://localhost:7689"
AUTH = ("neo4j", "12341234")

# %% [markdown]
# MongoDB Variables (change with your own config)

# %%
# Data collected from the nodejs project that read the twitter stream
# I used the 1% stream (which is free) to get the data through the Twitter Developer Portal

# database (change with database name)
db = client["twitter"]
# data of tweets collected
# Require at least the "in_reply_to_user_id" and the "text" field
# Optionally the "lang" field
tweets = db["tweets"]
# data of users
# Are obtainable with specific argument while reading the Twitter Stream
users = db["users"]
# Not used but I collected in relation tweets of the one I collected
# subs = db["tweetsSub"]

# %% [markdown]
# MongoDB functions

# %%
# Fetches the username from the user Id
def get_username_from_id(id):
    return users.find_one({"id" : id})["username"]

# Fetches the username mentionned in the text field of a tweet
def get_usernames_from_text(text):
    result = re.findall("@[a-zA-Z]*", text)
    rep = lambda e : e.replace("@", "")
    return map(rep, result)

# Fetches the username of the user that sent the tweet
def get_from_user (tweet):
    return get_username_from_id(tweet["author_id"])

# Fetches the usernames of the users that were mentioned in the tweet
def get_to_users(tweet) :
    return get_usernames_from_text(tweet["text"])

# %% [markdown]
# Neo4J functions

# %%
# Returns the weight of an user
def get_weight(tx, username):
    result = tx.run("MATCH (a:User) WHERE a.name = $name RETURN a.weight", name=username)
    single = result.single()
    if single is None : return None
    return single[0]

# Checks if an user already exists in the database
def exists(tx, username):
    return get_weight(tx, username) is not None

# Adds an user if it doesn't exist
# Updates if it already exists
def add_user(tx, username, lang = None):
    result =  tx.run(
        "MERGE (a:User {name: $name}) " +
        "ON CREATE " +
        "   SET a = {name: $name, weight : 0, lang : %s}" % ("null" if lang is None else "$lang")  +
        "ON MATCH " +
        "   SET a = {name: $name, weight : a.weight, lang : %s}" % ("a.lang" if lang is None else "$lang")  +
        "RETURN a.name, a.weight, a.lang",
        name = username,
        lang = lang
    )
    return result

# Adds a relation between to users
# Updates it if the realation already exists
def add_relation(tx, fr, to):
    result = tx.run(
        "MATCH (a:User), (b:User) " +
        "WHERE a.name = $a AND b.name = $b " +
        "MERGE (a)-[r:speaksOf]->(b) " +
        "   ON CREATE " +
        "       SET r.weight = 1, b.weight = b.weight + 1 " +
        "   ON MATCH " +
        "       SET r.weight = r.weight + 1, b.weight = b.weight + 1 " +
        "RETURN type(r) ",
        a = fr,
        b = to
    )
    return result

# Process a tweet into the Neo4J Database following the popularity algorithm
# In this function, we create users with a weight of 0 and each time they are mentionned, their weight increase by 1.
# Same thing happens for the relation. They are created with a weight of one and each time an user speaks to an user, this relations increase by 1.
async def process_user_popularity(tweet):
    fr = get_from_user(tweet)
    lang = tweet["lang"]
    to = get_to_users(tweet)
    async with AsyncGraphDatabase.driver(URI, auth=AUTH) as driver:
        async with driver.session() as session :
            await session.execute_write(add_user, fr, lang)
            for t in to :
                await session.execute_write(add_user, t)
                await session.execute_write(add_relation, fr, t)

# %% [markdown]
# Fetches the tweets which are interacting directly with one or many other users (can be with himself too. I did not make an exception on it).

# %%
tweetsToProcess = tweets.find({
    "$or" : [
        {"text" : { "$regex" : "^RT @"}},
        {"in_reply_to_user_id" : {"$exists" : True}}
    ]
})
maxCount = tweetsToProcess.count()
# Out:
# /tmp/ipykernel_15415/2925484801.py:7: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   maxCount = tweetsToProcess.count()

# %% [markdown]
# Creates the Graph database.

# %%
count = 0
last_count = 158592
# Process fails after a certain period of time (I don't know why)
# @TODO: Resuming automatically this process could be done...
for t in tweetsToProcess :
    if count > 0 : # Change the value to resume the process to the desired value
        await process_user_popularity(t)
    count += 1
    # Prints progress every 100 tweets processed
    if count % 100 == 0 :
        percent = count / maxCount * 100
        print (f"Processed tweet #{count} on {maxCount} ~ {percent:.2f}% done ")
# Out:
# Processed tweet #100 on 7334404 ~ 0.00% done
# Processed tweet #200 on 7334404 ~ 0.00% done
# Processed tweet #300 on 7334404 ~ 0.00% done
# Processed tweet #400 on 7334404 ~ 0.01% done
# Processed tweet #500 on 7334404 ~ 0.01% done
# Processed tweet #600 on 7334404 ~ 0.01% done
# Processed tweet #700 on 7334404 ~ 0.01% done
# Processed tweet #800 on 7334404 ~ 0.01% done
# Processed tweet #900 on 7334404 ~ 0.01% done
# Processed tweet #1000 on 7334404 ~ 0.01% done
# Processed tweet #1100 on 7334404 ~ 0.01% done
# Processed tweet #1200 on 7334404 ~ 0.02% done
# Processed tweet #1300 on 7334404 ~ 0.02% done
# Processed tweet #1400 on 7334404 ~ 0.02% done
# Processed tweet #1500 on 7334404 ~ 0.02% done
# Processed tweet #1600 on 7334404 ~ 0.02% done
# Processed tweet #1700 on 7334404 ~ 0.02% done
# Processed tweet #1800 on 7334404 ~ 0.02% done
# Processed tweet #1900 on 7334404 ~ 0.03% done
# Processed tweet #2000 on 7334404 ~ 0.03% done
# Processed tweet #2100 on 7334404 ~ 0.03% done
# Processed tweet #2200 on 7334404 ~ 0.03% done
# Processed tweet #2300 on 7334404 ~ 0.03% done
# Processed tweet #2400 on 7334404 ~ 0.03% done
# Processed tweet #2500 on 7334404 ~ 0.03% done
# Processed tweet #2600 on 7334404 ~ 0.04% done
# Processed tweet #2700 on 7334404 ~ 0.04% done
# Processed tweet #2800 on 7334404 ~ 0.04% done
# Processed tweet #2900 on 7334404 ~ 0.04% done
# Processed tweet #3000 on 7334404 ~ 0.04% done
# Processed tweet #3100 on 7334404 ~ 0.04% done
# Processed tweet #3200 on 7334404 ~ 0.04% done
# Processed tweet #3300 on 7334404 ~ 0.04% done
# Processed tweet #3400 on 7334404 ~ 0.05% done
# Processed tweet #3500 on 7334404 ~ 0.05% done
# Processed tweet #3600 on 7334404 ~ 0.05% done
# Processed tweet #3700 on 7334404 ~ 0.05% done
# Processed tweet #3800 on 7334404 ~ 0.05% done
# Processed tweet #3900 on 7334404 ~ 0.05% done
# Processed tweet #4000 on 7334404 ~ 0.05% done
# Processed tweet #4100 on 7334404 ~ 0.06% done
# Processed tweet #4200 on 7334404 ~ 0.06% done
# Processed tweet #4300 on 7334404 ~ 0.06% done
# Processed tweet #4400 on 7334404 ~ 0.06% done
# Processed tweet #4500 on 7334404 ~ 0.06% done
# Processed tweet #4600 on 7334404 ~ 0.06% done
# Processed tweet #4700 on 7334404 ~ 0.06% done
# Processed tweet #4800 on 7334404 ~ 0.07% done
# Processed tweet #4900 on 7334404 ~ 0.07% done
# Processed tweet #5000 on 7334404 ~ 0.07% done
# Processed tweet #5100 on 7334404 ~ 0.07% done
# Processed tweet #5200 on 7334404 ~ 0.07% done
# Processed tweet #5300 on 7334404 ~ 0.07% done
# Processed tweet #5400 on 7334404 ~ 0.07% done
# Processed tweet #5500 on 7334404 ~ 0.07% done
# Processed tweet #5600 on 7334404 ~ 0.08% done
# Processed tweet #5700 on 7334404 ~ 0.08% done
# Processed tweet #5800 on 7334404 ~ 0.08% done
# Processed tweet #5900 on 7334404 ~ 0.08% done
# Processed tweet #6000 on 7334404 ~ 0.08% done
# Processed tweet #6100 on 7334404 ~ 0.08% done
# Processed tweet #6200 on 7334404 ~ 0.08% done
# Processed tweet #6300 on 7334404 ~ 0.09% done
# Processed tweet #6400 on 7334404 ~ 0.09% done
# Processed tweet #6500 on 7334404 ~ 0.09% done
# Processed tweet #6600 on 7334404 ~ 0.09% done
# Processed tweet #6700 on 7334404 ~ 0.09% done
# Processed tweet #6800 on 7334404 ~ 0.09% done
# Processed tweet #6900 on 7334404 ~ 0.09% done
# Processed tweet #7000 on 7334404 ~ 0.10% done
# Processed tweet #7100 on 7334404 ~ 0.10% done
# Processed tweet #7200 on 7334404 ~ 0.10% done
# Processed tweet #7300 on 7334404 ~ 0.10% done
# Processed tweet #7400 on 7334404 ~ 0.10% done
# Processed tweet #7500 on 7334404 ~ 0.10% done
# Processed tweet #7600 on 7334404 ~ 0.10% done
# Processed tweet #7700 on 7334404 ~ 0.10% done
# Processed tweet #7800 on 7334404 ~ 0.11% done
# Processed tweet #7900 on 7334404 ~ 0.11% done
# Processed tweet #8000 on 7334404 ~ 0.11% done
# Processed tweet #8100 on 7334404 ~ 0.11% done
# Processed tweet #8200 on 7334404 ~ 0.11% done
# Processed tweet #8300 on 7334404 ~ 0.11% done
# Processed tweet #8400 on 7334404 ~ 0.11% done
# Processed tweet #8500 on 7334404 ~ 0.12% done
# Processed tweet #8600 on 7334404 ~ 0.12% done
# Processed tweet #8700 on 7334404 ~ 0.12% done
# Processed tweet #8800 on 7334404 ~ 0.12% done
# Processed tweet #8900 on 7334404 ~ 0.12% done
# Processed tweet #9000 on 7334404 ~ 0.12% done
# Processed tweet #9100 on 7334404 ~ 0.12% done
# Processed tweet #9200 on 7334404 ~ 0.13% done
# Processed tweet #9300 on 7334404 ~ 0.13% done
# Processed tweet #9400 on 7334404 ~ 0.13% done
# Processed tweet #9500 on 7334404 ~ 0.13% done
# Processed tweet #9600 on 7334404 ~ 0.13% done
# Processed tweet #9700 on 7334404 ~ 0.13% done
# Processed tweet #9800 on 7334404 ~ 0.13% done
# Processed tweet #9900 on 7334404 ~ 0.13% done
# Processed tweet #10000 on 7334404 ~ 0.14% done
# Processed tweet #10100 on 7334404 ~ 0.14% done
# Processed tweet #10200 on 7334404 ~ 0.14% done
# Processed tweet #10300 on 7334404 ~ 0.14% done
# Processed tweet #10400 on 7334404 ~ 0.14% done
# Processed tweet #10500 on 7334404 ~ 0.14% done
# Processed tweet #10600 on 7334404 ~ 0.14% done
# Processed tweet #10700 on 7334404 ~ 0.15% done
# Processed tweet #10800 on 7334404 ~ 0.15% done
# Processed tweet #10900 on 7334404 ~ 0.15% done
# Processed tweet #11000 on 7334404 ~ 0.15% done
# Processed tweet #11100 on 7334404 ~ 0.15% done
# Processed tweet #11200 on 7334404 ~ 0.15% done
# Processed tweet #11300 on 7334404 ~ 0.15% done
# Processed tweet #11400 on 7334404 ~ 0.16% done
# Processed tweet #11500 on 7334404 ~ 0.16% done
# Processed tweet #11600 on 7334404 ~ 0.16% done
# Processed tweet #11700 on 7334404 ~ 0.16% done
# Processed tweet #11800 on 7334404 ~ 0.16% done
# Processed tweet #11900 on 7334404 ~ 0.16% done
# Processed tweet #12000 on 7334404 ~ 0.16% done
# Processed tweet #12100 on 7334404 ~ 0.16% done
# Processed tweet #12200 on 7334404 ~ 0.17% done
# Processed tweet #12300 on 7334404 ~ 0.17% done
# Processed tweet #12400 on 7334404 ~ 0.17% done
# Processed tweet #12500 on 7334404 ~ 0.17% done
# Processed tweet #12600 on 7334404 ~ 0.17% done
# Processed tweet #12700 on 7334404 ~ 0.17% done
# Processed tweet #12800 on 7334404 ~ 0.17% done
# Processed tweet #12900 on 7334404 ~ 0.18% done
# Processed tweet #13000 on 7334404 ~ 0.18% done
# Processed tweet #13100 on 7334404 ~ 0.18% done
# Processed tweet #13200 on 7334404 ~ 0.18% done
# Processed tweet #13300 on 7334404 ~ 0.18% done
# Processed tweet #13400 on 7334404 ~ 0.18% done
# Processed tweet #13500 on 7334404 ~ 0.18% done
# Processed tweet #13600 on 7334404 ~ 0.19% done
# Processed tweet #13700 on 7334404 ~ 0.19% done
# Processed tweet #13800 on 7334404 ~ 0.19% done
# Processed tweet #13900 on 7334404 ~ 0.19% done
# Processed tweet #14000 on 7334404 ~ 0.19% done
# Processed tweet #14100 on 7334404 ~ 0.19% done
# Processed tweet #14200 on 7334404 ~ 0.19% done
# Processed tweet #14300 on 7334404 ~ 0.19% done
# Processed tweet #14400 on 7334404 ~ 0.20% done
# Processed tweet #14500 on 7334404 ~ 0.20% done
# Processed tweet #14600 on 7334404 ~ 0.20% done
# Processed tweet #14700 on 7334404 ~ 0.20% done
# Processed tweet #14800 on 7334404 ~ 0.20% done
# Processed tweet #14900 on 7334404 ~ 0.20% done
# Processed tweet #15000 on 7334404 ~ 0.20% done
# Processed tweet #15100 on 7334404 ~ 0.21% done
# Processed tweet #15200 on 7334404 ~ 0.21% done
# Processed tweet #15300 on 7334404 ~ 0.21% done
# Processed tweet #15400 on 7334404 ~ 0.21% done
# Processed tweet #15500 on 7334404 ~ 0.21% done
# Processed tweet #15600 on 7334404 ~ 0.21% done
# Processed tweet #15700 on 7334404 ~ 0.21% done
# Processed tweet #15800 on 7334404 ~ 0.22% done
# Processed tweet #15900 on 7334404 ~ 0.22% done
# Processed tweet #16000 on 7334404 ~ 0.22% done
# Processed tweet #16100 on 7334404 ~ 0.22% done
# Processed tweet #16200 on 7334404 ~ 0.22% done
# Processed tweet #16300 on 7334404 ~ 0.22% done
# Processed tweet #16400 on 7334404 ~ 0.22% done
# Processed tweet #16500 on 7334404 ~ 0.22% done
# Processed tweet #16600 on 7334404 ~ 0.23% done
# Processed tweet #16700 on 7334404 ~ 0.23% done
# Processed tweet #16800 on 7334404 ~ 0.23% done
# Processed tweet #16900 on 7334404 ~ 0.23% done
# Processed tweet #17000 on 7334404 ~ 0.23% done
# Processed tweet #17100 on 7334404 ~ 0.23% done
# Processed tweet #17200 on 7334404 ~ 0.23% done
# Processed tweet #17300 on 7334404 ~ 0.24% done
# Processed tweet #17400 on 7334404 ~ 0.24% done
# Processed tweet #17500 on 7334404 ~ 0.24% done
# Processed tweet #17600 on 7334404 ~ 0.24% done
# Processed tweet #17700 on 7334404 ~ 0.24% done
# Processed tweet #17800 on 7334404 ~ 0.24% done
# Processed tweet #17900 on 7334404 ~ 0.24% done
# Processed tweet #18000 on 7334404 ~ 0.25% done
# Processed tweet #18100 on 7334404 ~ 0.25% done
# Processed tweet #18200 on 7334404 ~ 0.25% done
# Processed tweet #18300 on 7334404 ~ 0.25% done
# Processed tweet #18400 on 7334404 ~ 0.25% done
# Processed tweet #18500 on 7334404 ~ 0.25% done
# Processed tweet #18600 on 7334404 ~ 0.25% done
# Processed tweet #18700 on 7334404 ~ 0.25% done
# Processed tweet #18800 on 7334404 ~ 0.26% done
# Processed tweet #18900 on 7334404 ~ 0.26% done
# Processed tweet #19000 on 7334404 ~ 0.26% done
# Processed tweet #19100 on 7334404 ~ 0.26% done
# Processed tweet #19200 on 7334404 ~ 0.26% done
# Processed tweet #19300 on 7334404 ~ 0.26% done
# Processed tweet #19400 on 7334404 ~ 0.26% done
# Processed tweet #19500 on 7334404 ~ 0.27% done
# Processed tweet #19600 on 7334404 ~ 0.27% done
# Processed tweet #19700 on 7334404 ~ 0.27% done
# Processed tweet #19800 on 7334404 ~ 0.27% done
# Processed tweet #19900 on 7334404 ~ 0.27% done
# Processed tweet #20000 on 7334404 ~ 0.27% done
# Processed tweet #20100 on 7334404 ~ 0.27% done
# Processed tweet #20200 on 7334404 ~ 0.28% done
# Processed tweet #20300 on 7334404 ~ 0.28% done
# Processed tweet #20400 on 7334404 ~ 0.28% done
# Processed tweet #20500 on 7334404 ~ 0.28% done
# Processed tweet #20600 on 7334404 ~ 0.28% done
# Processed tweet #20700 on 7334404 ~ 0.28% done
# Processed tweet #20800 on 7334404 ~ 0.28% done
# Processed tweet #20900 on 7334404 ~ 0.28% done
# Processed tweet #21000 on 7334404 ~ 0.29% done
# Processed tweet #21100 on 7334404 ~ 0.29% done
# Processed tweet #21200 on 7334404 ~ 0.29% done
# Processed tweet #21300 on 7334404 ~ 0.29% done
# Processed tweet #21400 on 7334404 ~ 0.29% done
# Processed tweet #21500 on 7334404 ~ 0.29% done
# Processed tweet #21600 on 7334404 ~ 0.29% done
# Processed tweet #21700 on 7334404 ~ 0.30% done
# Processed tweet #21800 on 7334404 ~ 0.30% done
# Processed tweet #21900 on 7334404 ~ 0.30% done
# Processed tweet #22000 on 7334404 ~ 0.30% done
# Processed tweet #22100 on 7334404 ~ 0.30% done
# Processed tweet #22200 on 7334404 ~ 0.30% done
# Processed tweet #22300 on 7334404 ~ 0.30% done
# Processed tweet #22400 on 7334404 ~ 0.31% done
# Processed tweet #22500 on 7334404 ~ 0.31% done
# Processed tweet #22600 on 7334404 ~ 0.31% done
# Processed tweet #22700 on 7334404 ~ 0.31% done
# Processed tweet #22800 on 7334404 ~ 0.31% done
# Processed tweet #22900 on 7334404 ~ 0.31% done
# Processed tweet #23000 on 7334404 ~ 0.31% done
# Processed tweet #23100 on 7334404 ~ 0.31% done
# Processed tweet #23200 on 7334404 ~ 0.32% done
# Processed tweet #23300 on 7334404 ~ 0.32% done
# Processed tweet #23400 on 7334404 ~ 0.32% done
# Processed tweet #23500 on 7334404 ~ 0.32% done
# Processed tweet #23600 on 7334404 ~ 0.32% done
# Processed tweet #23700 on 7334404 ~ 0.32% done
# Processed tweet #23800 on 7334404 ~ 0.32% done
# Processed tweet #23900 on 7334404 ~ 0.33% done
# Processed tweet #24000 on 7334404 ~ 0.33% done
# Processed tweet #24100 on 7334404 ~ 0.33% done
# Processed tweet #24200 on 7334404 ~ 0.33% done
# Processed tweet #24300 on 7334404 ~ 0.33% done
# Processed tweet #24400 on 7334404 ~ 0.33% done
# Processed tweet #24500 on 7334404 ~ 0.33% done
# Processed tweet #24600 on 7334404 ~ 0.34% done
# Processed tweet #24700 on 7334404 ~ 0.34% done
# Processed tweet #24800 on 7334404 ~ 0.34% done
# Processed tweet #24900 on 7334404 ~ 0.34% done
# Processed tweet #25000 on 7334404 ~ 0.34% done
# Processed tweet #25100 on 7334404 ~ 0.34% done
# Processed tweet #25200 on 7334404 ~ 0.34% done
# Processed tweet #25300 on 7334404 ~ 0.34% done
# Processed tweet #25400 on 7334404 ~ 0.35% done
# Processed tweet #25500 on 7334404 ~ 0.35% done
# Processed tweet #25600 on 7334404 ~ 0.35% done
# Processed tweet #25700 on 7334404 ~ 0.35% done
# Processed tweet #25800 on 7334404 ~ 0.35% done
# Processed tweet #25900 on 7334404 ~ 0.35% done
# Processed tweet #26000 on 7334404 ~ 0.35% done
# Processed tweet #26100 on 7334404 ~ 0.36% done
# Processed tweet #26200 on 7334404 ~ 0.36% done
# Processed tweet #26300 on 7334404 ~ 0.36% done
# Processed tweet #26400 on 7334404 ~ 0.36% done
# Processed tweet #26500 on 7334404 ~ 0.36% done
# Processed tweet #26600 on 7334404 ~ 0.36% done
# Processed tweet #32500 on 7334404 ~ 0.44% done
# Processed tweet #32600 on 7334404 ~ 0.44% done
# Processed tweet #32700 on 7334404 ~ 0.45% done
# Processed tweet #32800 on 7334404 ~ 0.45% done
# Processed tweet #32900 on 7334404 ~ 0.45% done
# Processed tweet #33000 on 7334404 ~ 0.45% done
# Processed tweet #33100 on 7334404 ~ 0.45% done
# Processed tweet #33200 on 7334404 ~ 0.45% done
# Processed tweet #33300 on 7334404 ~ 0.45% done
# Processed tweet #33400 on 7334404 ~ 0.46% done
# Processed tweet #33500 on 7334404 ~ 0.46% done
# Processed tweet #33600 on 7334404 ~ 0.46% done
# Processed tweet #33700 on 7334404 ~ 0.46% done
# Processed tweet #33800 on 7334404 ~ 0.46% done
# Processed tweet #33900 on 7334404 ~ 0.46% done
# Processed tweet #34000 on 7334404 ~ 0.46% done
# Processed tweet #34100 on 7334404 ~ 0.46% done
# Processed tweet #34200 on 7334404 ~ 0.47% done
# Processed tweet #34300 on 7334404 ~ 0.47% done
# Processed tweet #34400 on 7334404 ~ 0.47% done
# Processed tweet #34500 on 7334404 ~ 0.47% done
# Processed tweet #34600 on 7334404 ~ 0.47% done
# Processed tweet #34700 on 7334404 ~ 0.47% done
# Processed tweet #34800 on 7334404 ~ 0.47% done
# Processed tweet #34900 on 7334404 ~ 0.48% done
# Processed tweet #35000 on 7334404 ~ 0.48% done
# Processed tweet #35100 on 7334404 ~ 0.48% done
# Processed tweet #35200 on 7334404 ~ 0.48% done
# Processed tweet #35300 on 7334404 ~ 0.48% done
# Processed tweet #35400 on 7334404 ~ 0.48% done
# Processed tweet #35500 on 7334404 ~ 0.48% done
# Processed tweet #35600 on 7334404 ~ 0.49% done
# Processed tweet #35700 on 7334404 ~ 0.49% done
# Processed tweet #35800 on 7334404 ~ 0.49% done
# Processed tweet #35900 on 7334404 ~ 0.49% done
# Processed tweet #36000 on 7334404 ~ 0.49% done
# Processed tweet #36100 on 7334404 ~ 0.49% done
# Processed tweet #36200 on 7334404 ~ 0.49% done
# Processed tweet #36300 on 7334404 ~ 0.49% done
# Processed tweet #36400 on 7334404 ~ 0.50% done
# Processed tweet #36500 on 7334404 ~ 0.50% done
# Processed tweet #36600 on 7334404 ~ 0.50% done
# Processed tweet #36700 on 7334404 ~ 0.50% done
# Processed tweet #36800 on 7334404 ~ 0.50% done
# Processed tweet #36900 on 7334404 ~ 0.50% done
# Processed tweet #37000 on 7334404 ~ 0.50% done
# Processed tweet #37100 on 7334404 ~ 0.51% done
# Processed tweet #37200 on 7334404 ~ 0.51% done
# Processed tweet #37300 on 7334404 ~ 0.51% done
# Processed tweet #37400 on 7334404 ~ 0.51% done
# Processed tweet #37500 on 7334404 ~ 0.51% done
# Processed tweet #37600 on 7334404 ~ 0.51% done
# Processed tweet #37700 on 7334404 ~ 0.51% done
# Processed tweet #37800 on 7334404 ~ 0.52% done
# Processed tweet #37900 on 7334404 ~ 0.52% done
# Processed tweet #38000 on 7334404 ~ 0.52% done
# Processed tweet #38100 on 7334404 ~ 0.52% done
# Processed tweet #38200 on 7334404 ~ 0.52% done
# Processed tweet #38300 on 7334404 ~ 0.52% done
# Processed tweet #38400 on 7334404 ~ 0.52% done
# Processed tweet #38500 on 7334404 ~ 0.52% done
# Processed tweet #38600 on 7334404 ~ 0.53% done
# Processed tweet #38700 on 7334404 ~ 0.53% done
# Processed tweet #38800 on 7334404 ~ 0.53% done
# Processed tweet #38900 on 7334404 ~ 0.53% done
# Processed tweet #39000 on 7334404 ~ 0.53% done
# Processed tweet #39100 on 7334404 ~ 0.53% done
# Processed tweet #39200 on 7334404 ~ 0.53% done
# Processed tweet #39300 on 7334404 ~ 0.54% done
# Processed tweet #39400 on 7334404 ~ 0.54% done
# Processed tweet #39500 on 7334404 ~ 0.54% done
# Processed tweet #39600 on 7334404 ~ 0.54% done
# Processed tweet #39700 on 7334404 ~ 0.54% done
# Processed tweet #39800 on 7334404 ~ 0.54% done
# Processed tweet #39900 on 7334404 ~ 0.54% done
# Processed tweet #40000 on 7334404 ~ 0.55% done
# Processed tweet #40100 on 7334404 ~ 0.55% done
# Processed tweet #40200 on 7334404 ~ 0.55% done
# Processed tweet #40300 on 7334404 ~ 0.55% done
# Processed tweet #40400 on 7334404 ~ 0.55% done
# Processed tweet #40500 on 7334404 ~ 0.55% done
# Processed tweet #40600 on 7334404 ~ 0.55% done
# Processed tweet #40700 on 7334404 ~ 0.55% done
# Processed tweet #40800 on 7334404 ~ 0.56% done
# Processed tweet #40900 on 7334404 ~ 0.56% done
# Processed tweet #41000 on 7334404 ~ 0.56% done
# Processed tweet #41100 on 7334404 ~ 0.56% done
# Processed tweet #41200 on 7334404 ~ 0.56% done
# Processed tweet #41300 on 7334404 ~ 0.56% done
# Processed tweet #41400 on 7334404 ~ 0.56% done
# Processed tweet #41500 on 7334404 ~ 0.57% done
# Processed tweet #41600 on 7334404 ~ 0.57% done
# Processed tweet #41700 on 7334404 ~ 0.57% done
# Processed tweet #41800 on 7334404 ~ 0.57% done
# Processed tweet #41900 on 7334404 ~ 0.57% done
# Processed tweet #42000 on 7334404 ~ 0.57% done
# Processed tweet #42100 on 7334404 ~ 0.57% done
# Processed tweet #42200 on 7334404 ~ 0.58% done
# Processed tweet #42300 on 7334404 ~ 0.58% done
# Processed tweet #42400 on 7334404 ~ 0.58% done
# Processed tweet #42500 on 7334404 ~ 0.58% done
# Processed tweet #42600 on 7334404 ~ 0.58% done
# Processed tweet #42700 on 7334404 ~ 0.58% done
# Processed tweet #42800 on 7334404 ~ 0.58% done
# Processed tweet #42900 on 7334404 ~ 0.58% done
# Processed tweet #43000 on 7334404 ~ 0.59% done
# Processed tweet #43100 on 7334404 ~ 0.59% done
# Processed tweet #43200 on 7334404 ~ 0.59% done
# Processed tweet #43300 on 7334404 ~ 0.59% done
# Processed tweet #43400 on 7334404 ~ 0.59% done
# Processed tweet #43500 on 7334404 ~ 0.59% done
# Processed tweet #43600 on 7334404 ~ 0.59% done
# Processed tweet #43700 on 7334404 ~ 0.60% done
# Processed tweet #43800 on 7334404 ~ 0.60% done
# Processed tweet #43900 on 7334404 ~ 0.60% done
# Processed tweet #44000 on 7334404 ~ 0.60% done
# Processed tweet #49800 on 7334404 ~ 0.68% done
# Processed tweet #49900 on 7334404 ~ 0.68% done
# Processed tweet #50000 on 7334404 ~ 0.68% done
# Processed tweet #50100 on 7334404 ~ 0.68% done
# Processed tweet #50200 on 7334404 ~ 0.68% done
# Processed tweet #50300 on 7334404 ~ 0.69% done
# Processed tweet #50400 on 7334404 ~ 0.69% done
# Processed tweet #50500 on 7334404 ~ 0.69% done
# Processed tweet #50600 on 7334404 ~ 0.69% done
# Processed tweet #50700 on 7334404 ~ 0.69% done
# Processed tweet #50800 on 7334404 ~ 0.69% done
# Processed tweet #50900 on 7334404 ~ 0.69% done
# Processed tweet #51000 on 7334404 ~ 0.70% done
# Processed tweet #51100 on 7334404 ~ 0.70% done
# Processed tweet #51200 on 7334404 ~ 0.70% done
# Processed tweet #51300 on 7334404 ~ 0.70% done
# Processed tweet #51400 on 7334404 ~ 0.70% done
# Processed tweet #51500 on 7334404 ~ 0.70% done
# Processed tweet #51600 on 7334404 ~ 0.70% done
# Processed tweet #51700 on 7334404 ~ 0.70% done
# Processed tweet #51800 on 7334404 ~ 0.71% done
# Processed tweet #51900 on 7334404 ~ 0.71% done
# Processed tweet #52000 on 7334404 ~ 0.71% done
# Processed tweet #52100 on 7334404 ~ 0.71% done
# Processed tweet #52200 on 7334404 ~ 0.71% done
# Processed tweet #52300 on 7334404 ~ 0.71% done
# Processed tweet #52400 on 7334404 ~ 0.71% done
# Processed tweet #52500 on 7334404 ~ 0.72% done
# Processed tweet #52600 on 7334404 ~ 0.72% done
# Processed tweet #52700 on 7334404 ~ 0.72% done
# Processed tweet #52800 on 7334404 ~ 0.72% done
# Processed tweet #52900 on 7334404 ~ 0.72% done
# Processed tweet #53000 on 7334404 ~ 0.72% done
# Processed tweet #53100 on 7334404 ~ 0.72% done
# Processed tweet #53200 on 7334404 ~ 0.73% done
# Processed tweet #53300 on 7334404 ~ 0.73% done
# Processed tweet #53400 on 7334404 ~ 0.73% done
# Processed tweet #53500 on 7334404 ~ 0.73% done
# Processed tweet #53600 on 7334404 ~ 0.73% done
# Processed tweet #53700 on 7334404 ~ 0.73% done
# Processed tweet #53800 on 7334404 ~ 0.73% done
# Processed tweet #53900 on 7334404 ~ 0.73% done
# Processed tweet #54000 on 7334404 ~ 0.74% done
# Processed tweet #54100 on 7334404 ~ 0.74% done
# Processed tweet #54200 on 7334404 ~ 0.74% done
# Processed tweet #54300 on 7334404 ~ 0.74% done
# Processed tweet #54400 on 7334404 ~ 0.74% done
# Processed tweet #54500 on 7334404 ~ 0.74% done
# Processed tweet #54600 on 7334404 ~ 0.74% done
# Processed tweet #54700 on 7334404 ~ 0.75% done
# Processed tweet #54800 on 7334404 ~ 0.75% done
# Processed tweet #54900 on 7334404 ~ 0.75% done
# Processed tweet #55000 on 7334404 ~ 0.75% done
# Processed tweet #55100 on 7334404 ~ 0.75% done
# Processed tweet #55200 on 7334404 ~ 0.75% done
# Processed tweet #55300 on 7334404 ~ 0.75% done
# Processed tweet #55400 on 7334404 ~ 0.76% done
# Processed tweet #55500 on 7334404 ~ 0.76% done
# Processed tweet #55600 on 7334404 ~ 0.76% done
# Processed tweet #55700 on 7334404 ~ 0.76% done
# Processed tweet #55800 on 7334404 ~ 0.76% done
# Processed tweet #55900 on 7334404 ~ 0.76% done
# Processed tweet #56000 on 7334404 ~ 0.76% done
# Processed tweet #56100 on 7334404 ~ 0.76% done
# Processed tweet #56200 on 7334404 ~ 0.77% done
# Processed tweet #56300 on 7334404 ~ 0.77% done
# Processed tweet #56400 on 7334404 ~ 0.77% done
# Processed tweet #56500 on 7334404 ~ 0.77% done
# Processed tweet #56600 on 7334404 ~ 0.77% done
# Processed tweet #56700 on 7334404 ~ 0.77% done
# Processed tweet #56800 on 7334404 ~ 0.77% done
# Processed tweet #56900 on 7334404 ~ 0.78% done
# Processed tweet #57000 on 7334404 ~ 0.78% done
# Processed tweet #57100 on 7334404 ~ 0.78% done
# Processed tweet #57200 on 7334404 ~ 0.78% done
# Processed tweet #57300 on 7334404 ~ 0.78% done
# Processed tweet #57400 on 7334404 ~ 0.78% done
# Processed tweet #57500 on 7334404 ~ 0.78% done
# Processed tweet #57600 on 7334404 ~ 0.79% done
# Processed tweet #57700 on 7334404 ~ 0.79% done
# Processed tweet #57800 on 7334404 ~ 0.79% done
# Processed tweet #57900 on 7334404 ~ 0.79% done
# Processed tweet #58000 on 7334404 ~ 0.79% done
# Processed tweet #58100 on 7334404 ~ 0.79% done
# Processed tweet #58200 on 7334404 ~ 0.79% done
# Processed tweet #58300 on 7334404 ~ 0.79% done
# Processed tweet #58400 on 7334404 ~ 0.80% done
# Processed tweet #58500 on 7334404 ~ 0.80% done
# Processed tweet #58600 on 7334404 ~ 0.80% done
# Processed tweet #58700 on 7334404 ~ 0.80% done
# Processed tweet #58800 on 7334404 ~ 0.80% done
# Processed tweet #58900 on 7334404 ~ 0.80% done
# Processed tweet #59000 on 7334404 ~ 0.80% done
# Processed tweet #59100 on 7334404 ~ 0.81% done
# Processed tweet #59200 on 7334404 ~ 0.81% done
# Processed tweet #59300 on 7334404 ~ 0.81% done
# Processed tweet #59400 on 7334404 ~ 0.81% done
# Processed tweet #59500 on 7334404 ~ 0.81% done
# Processed tweet #59600 on 7334404 ~ 0.81% done
# Processed tweet #59700 on 7334404 ~ 0.81% done
# Processed tweet #59800 on 7334404 ~ 0.82% done
# Processed tweet #59900 on 7334404 ~ 0.82% done
# Processed tweet #60000 on 7334404 ~ 0.82% done
# Processed tweet #60100 on 7334404 ~ 0.82% done
# Processed tweet #60200 on 7334404 ~ 0.82% done
# Processed tweet #60300 on 7334404 ~ 0.82% done
# Processed tweet #60400 on 7334404 ~ 0.82% done
# Processed tweet #60500 on 7334404 ~ 0.82% done
# Processed tweet #60600 on 7334404 ~ 0.83% done
# Processed tweet #60700 on 7334404 ~ 0.83% done
# Processed tweet #60800 on 7334404 ~ 0.83% done
# Processed tweet #60900 on 7334404 ~ 0.83% done
# Processed tweet #61000 on 7334404 ~ 0.83% done
# Processed tweet #61100 on 7334404 ~ 0.83% done
# Processed tweet #61200 on 7334404 ~ 0.83% done
# Processed tweet #61300 on 7334404 ~ 0.84% done
# Processed tweet #61400 on 7334404 ~ 0.84% done
# Processed tweet #61500 on 7334404 ~ 0.84% done
# Processed tweet #61600 on 7334404 ~ 0.84% done
# Processed tweet #61700 on 7334404 ~ 0.84% done
# Processed tweet #61800 on 7334404 ~ 0.84% done
# Processed tweet #61900 on 7334404 ~ 0.84% done
# Processed tweet #62000 on 7334404 ~ 0.85% done
# Processed tweet #62100 on 7334404 ~ 0.85% done
# Processed tweet #62200 on 7334404 ~ 0.85% done
# Processed tweet #62300 on 7334404 ~ 0.85% done
# Processed tweet #62400 on 7334404 ~ 0.85% done
# Processed tweet #62500 on 7334404 ~ 0.85% done
# Processed tweet #62600 on 7334404 ~ 0.85% done
# Processed tweet #62700 on 7334404 ~ 0.85% done
# Processed tweet #62800 on 7334404 ~ 0.86% done
# Processed tweet #62900 on 7334404 ~ 0.86% done
# Processed tweet #63000 on 7334404 ~ 0.86% done
# Processed tweet #63100 on 7334404 ~ 0.86% done
# Processed tweet #63200 on 7334404 ~ 0.86% done
# Processed tweet #63300 on 7334404 ~ 0.86% done
# Processed tweet #63400 on 7334404 ~ 0.86% done
# Processed tweet #63500 on 7334404 ~ 0.87% done
# Processed tweet #63600 on 7334404 ~ 0.87% done
# Processed tweet #63700 on 7334404 ~ 0.87% done
# Processed tweet #63800 on 7334404 ~ 0.87% done
# Processed tweet #63900 on 7334404 ~ 0.87% done
# Processed tweet #64000 on 7334404 ~ 0.87% done
# Processed tweet #64100 on 7334404 ~ 0.87% done
# Processed tweet #64200 on 7334404 ~ 0.88% done
# Processed tweet #64300 on 7334404 ~ 0.88% done
# Processed tweet #64400 on 7334404 ~ 0.88% done
# Processed tweet #64500 on 7334404 ~ 0.88% done
# Processed tweet #64600 on 7334404 ~ 0.88% done
# Processed tweet #64700 on 7334404 ~ 0.88% done
# Processed tweet #64800 on 7334404 ~ 0.88% done
# Processed tweet #64900 on 7334404 ~ 0.88% done
# Processed tweet #65000 on 7334404 ~ 0.89% done
# Processed tweet #65100 on 7334404 ~ 0.89% done
# Processed tweet #65200 on 7334404 ~ 0.89% done
# Processed tweet #65300 on 7334404 ~ 0.89% done
# Processed tweet #65400 on 7334404 ~ 0.89% done
# Processed tweet #65500 on 7334404 ~ 0.89% done
# Processed tweet #65600 on 7334404 ~ 0.89% done
# Processed tweet #65700 on 7334404 ~ 0.90% done
# Processed tweet #65800 on 7334404 ~ 0.90% done
# Processed tweet #65900 on 7334404 ~ 0.90% done
# Processed tweet #66000 on 7334404 ~ 0.90% done
# Processed tweet #66100 on 7334404 ~ 0.90% done
# Processed tweet #66200 on 7334404 ~ 0.90% done
# Processed tweet #66300 on 7334404 ~ 0.90% done
# Processed tweet #66400 on 7334404 ~ 0.91% done
# Processed tweet #66500 on 7334404 ~ 0.91% done
# Processed tweet #66600 on 7334404 ~ 0.91% done
# Processed tweet #66700 on 7334404 ~ 0.91% done
# Processed tweet #66800 on 7334404 ~ 0.91% done
# Processed tweet #66900 on 7334404 ~ 0.91% done
# Processed tweet #67000 on 7334404 ~ 0.91% done
# Processed tweet #67100 on 7334404 ~ 0.91% done
# Processed tweet #67200 on 7334404 ~ 0.92% done
# Processed tweet #67300 on 7334404 ~ 0.92% done
# Processed tweet #67400 on 7334404 ~ 0.92% done
# Processed tweet #67500 on 7334404 ~ 0.92% done
# Processed tweet #67600 on 7334404 ~ 0.92% done
# Processed tweet #67700 on 7334404 ~ 0.92% done
# Processed tweet #67800 on 7334404 ~ 0.92% done
# Processed tweet #67900 on 7334404 ~ 0.93% done
# Processed tweet #68000 on 7334404 ~ 0.93% done
# Processed tweet #68100 on 7334404 ~ 0.93% done
# Processed tweet #68200 on 7334404 ~ 0.93% done
# Processed tweet #68300 on 7334404 ~ 0.93% done
# Processed tweet #68400 on 7334404 ~ 0.93% done
# Processed tweet #68500 on 7334404 ~ 0.93% done
# Processed tweet #68600 on 7334404 ~ 0.94% done
# Processed tweet #68700 on 7334404 ~ 0.94% done
# Processed tweet #68800 on 7334404 ~ 0.94% done
# Processed tweet #68900 on 7334404 ~ 0.94% done
# Processed tweet #69000 on 7334404 ~ 0.94% done
# Processed tweet #69100 on 7334404 ~ 0.94% done
# Processed tweet #69200 on 7334404 ~ 0.94% done
# Processed tweet #69300 on 7334404 ~ 0.94% done
# Processed tweet #69400 on 7334404 ~ 0.95% done
# Processed tweet #69500 on 7334404 ~ 0.95% done
# Processed tweet #69600 on 7334404 ~ 0.95% done
# Processed tweet #69700 on 7334404 ~ 0.95% done
# Processed tweet #69800 on 7334404 ~ 0.95% done
# Processed tweet #69900 on 7334404 ~ 0.95% done
# Processed tweet #70000 on 7334404 ~ 0.95% done
# Processed tweet #70100 on 7334404 ~ 0.96% done
# Processed tweet #70200 on 7334404 ~ 0.96% done
# Processed tweet #70300 on 7334404 ~ 0.96% done
# Processed tweet #70400 on 7334404 ~ 0.96% done
# Processed tweet #70500 on 7334404 ~ 0.96% done
# Processed tweet #70600 on 7334404 ~ 0.96% done
# Processed tweet #70700 on 7334404 ~ 0.96% done
# Processed tweet #70800 on 7334404 ~ 0.97% done
# Processed tweet #70900 on 7334404 ~ 0.97% done
# Processed tweet #71000 on 7334404 ~ 0.97% done
# Processed tweet #71100 on 7334404 ~ 0.97% done
# Processed tweet #71200 on 7334404 ~ 0.97% done
# Processed tweet #71300 on 7334404 ~ 0.97% done
# Processed tweet #71400 on 7334404 ~ 0.97% done
# Processed tweet #71500 on 7334404 ~ 0.97% done
# Processed tweet #71600 on 7334404 ~ 0.98% done
# Processed tweet #71700 on 7334404 ~ 0.98% done
# Processed tweet #71800 on 7334404 ~ 0.98% done
# Processed tweet #71900 on 7334404 ~ 0.98% done
# Processed tweet #72000 on 7334404 ~ 0.98% done
# Processed tweet #72100 on 7334404 ~ 0.98% done
# Processed tweet #72200 on 7334404 ~ 0.98% done
# Processed tweet #72300 on 7334404 ~ 0.99% done
# Processed tweet #72400 on 7334404 ~ 0.99% done
# Processed tweet #72500 on 7334404 ~ 0.99% done
# Processed tweet #72600 on 7334404 ~ 0.99% done
# Processed tweet #72700 on 7334404 ~ 0.99% done
# Processed tweet #72800 on 7334404 ~ 0.99% done
# Processed tweet #72900 on 7334404 ~ 0.99% done
# Processed tweet #78700 on 7334404 ~ 1.07% done
# Processed tweet #78800 on 7334404 ~ 1.07% done
# Processed tweet #78900 on 7334404 ~ 1.08% done
# Processed tweet #79000 on 7334404 ~ 1.08% done
# Processed tweet #79100 on 7334404 ~ 1.08% done
# Processed tweet #79200 on 7334404 ~ 1.08% done
# Processed tweet #79300 on 7334404 ~ 1.08% done
# Processed tweet #79400 on 7334404 ~ 1.08% done
# Processed tweet #79500 on 7334404 ~ 1.08% done
# Processed tweet #79600 on 7334404 ~ 1.09% done
# Processed tweet #79700 on 7334404 ~ 1.09% done
# Processed tweet #79800 on 7334404 ~ 1.09% done
# Processed tweet #79900 on 7334404 ~ 1.09% done
# Processed tweet #80000 on 7334404 ~ 1.09% done
# Processed tweet #80100 on 7334404 ~ 1.09% done
# Processed tweet #80200 on 7334404 ~ 1.09% done
# Processed tweet #80300 on 7334404 ~ 1.09% done
# Processed tweet #80400 on 7334404 ~ 1.10% done
# Processed tweet #80500 on 7334404 ~ 1.10% done
# Processed tweet #80600 on 7334404 ~ 1.10% done
# Processed tweet #80700 on 7334404 ~ 1.10% done
# Processed tweet #80800 on 7334404 ~ 1.10% done
# Processed tweet #80900 on 7334404 ~ 1.10% done
# Processed tweet #81000 on 7334404 ~ 1.10% done
# Processed tweet #81100 on 7334404 ~ 1.11% done
# Processed tweet #81200 on 7334404 ~ 1.11% done
# Processed tweet #81300 on 7334404 ~ 1.11% done
# Processed tweet #81400 on 7334404 ~ 1.11% done
# Processed tweet #81500 on 7334404 ~ 1.11% done
# Processed tweet #81600 on 7334404 ~ 1.11% done
# Processed tweet #81700 on 7334404 ~ 1.11% done
# Processed tweet #81800 on 7334404 ~ 1.12% done
# Processed tweet #81900 on 7334404 ~ 1.12% done
# Processed tweet #82000 on 7334404 ~ 1.12% done
# Processed tweet #82100 on 7334404 ~ 1.12% done
# Processed tweet #82200 on 7334404 ~ 1.12% done
# Processed tweet #82300 on 7334404 ~ 1.12% done
# Processed tweet #82400 on 7334404 ~ 1.12% done
# Processed tweet #82500 on 7334404 ~ 1.12% done
# Processed tweet #82600 on 7334404 ~ 1.13% done
# Processed tweet #82700 on 7334404 ~ 1.13% done
# Processed tweet #82800 on 7334404 ~ 1.13% done
# Processed tweet #82900 on 7334404 ~ 1.13% done
# Processed tweet #83000 on 7334404 ~ 1.13% done
# Processed tweet #83100 on 7334404 ~ 1.13% done
# Processed tweet #83200 on 7334404 ~ 1.13% done
# Processed tweet #83300 on 7334404 ~ 1.14% done
# Processed tweet #83400 on 7334404 ~ 1.14% done
# Processed tweet #83500 on 7334404 ~ 1.14% done
# Processed tweet #83600 on 7334404 ~ 1.14% done
# Processed tweet #83700 on 7334404 ~ 1.14% done
# Processed tweet #83800 on 7334404 ~ 1.14% done
# Processed tweet #83900 on 7334404 ~ 1.14% done
# Processed tweet #84000 on 7334404 ~ 1.15% done
# Processed tweet #84100 on 7334404 ~ 1.15% done
# Processed tweet #84200 on 7334404 ~ 1.15% done
# Processed tweet #84300 on 7334404 ~ 1.15% done
# Processed tweet #84400 on 7334404 ~ 1.15% done
# Processed tweet #90300 on 7334404 ~ 1.23% done
# Processed tweet #90400 on 7334404 ~ 1.23% done
# Processed tweet #90500 on 7334404 ~ 1.23% done
# Processed tweet #90600 on 7334404 ~ 1.24% done
# Processed tweet #90700 on 7334404 ~ 1.24% done
# Processed tweet #90800 on 7334404 ~ 1.24% done
# Processed tweet #90900 on 7334404 ~ 1.24% done
# Processed tweet #91000 on 7334404 ~ 1.24% done
# Processed tweet #91100 on 7334404 ~ 1.24% done
# Processed tweet #91200 on 7334404 ~ 1.24% done
# Processed tweet #91300 on 7334404 ~ 1.24% done
# Processed tweet #91400 on 7334404 ~ 1.25% done
# Processed tweet #91500 on 7334404 ~ 1.25% done
# Processed tweet #91600 on 7334404 ~ 1.25% done
# Processed tweet #91700 on 7334404 ~ 1.25% done
# Processed tweet #91800 on 7334404 ~ 1.25% done
# Processed tweet #91900 on 7334404 ~ 1.25% done
# Processed tweet #92000 on 7334404 ~ 1.25% done
# Processed tweet #92100 on 7334404 ~ 1.26% done
# Processed tweet #92200 on 7334404 ~ 1.26% done
# Processed tweet #92300 on 7334404 ~ 1.26% done
# Processed tweet #92400 on 7334404 ~ 1.26% done
# Processed tweet #92500 on 7334404 ~ 1.26% done
# Processed tweet #92600 on 7334404 ~ 1.26% done
# Processed tweet #92700 on 7334404 ~ 1.26% done
# Processed tweet #92800 on 7334404 ~ 1.27% done
# Processed tweet #92900 on 7334404 ~ 1.27% done
# Processed tweet #93000 on 7334404 ~ 1.27% done
# Processed tweet #93100 on 7334404 ~ 1.27% done
# Processed tweet #93200 on 7334404 ~ 1.27% done
# Processed tweet #93300 on 7334404 ~ 1.27% done
# Processed tweet #93400 on 7334404 ~ 1.27% done
# Processed tweet #93500 on 7334404 ~ 1.27% done
# Processed tweet #93600 on 7334404 ~ 1.28% done
# Processed tweet #93700 on 7334404 ~ 1.28% done
# Processed tweet #93800 on 7334404 ~ 1.28% done
# Processed tweet #93900 on 7334404 ~ 1.28% done
# Processed tweet #94000 on 7334404 ~ 1.28% done
# Processed tweet #94100 on 7334404 ~ 1.28% done
# Processed tweet #94200 on 7334404 ~ 1.28% done
# Processed tweet #94300 on 7334404 ~ 1.29% done
# Processed tweet #94400 on 7334404 ~ 1.29% done
# Processed tweet #94500 on 7334404 ~ 1.29% done
# Processed tweet #94600 on 7334404 ~ 1.29% done
# Processed tweet #94700 on 7334404 ~ 1.29% done
# Processed tweet #94800 on 7334404 ~ 1.29% done
# Processed tweet #94900 on 7334404 ~ 1.29% done
# Processed tweet #95000 on 7334404 ~ 1.30% done
# Processed tweet #95100 on 7334404 ~ 1.30% done
# Processed tweet #95200 on 7334404 ~ 1.30% done
# Processed tweet #95300 on 7334404 ~ 1.30% done
# Processed tweet #95400 on 7334404 ~ 1.30% done
# Processed tweet #95500 on 7334404 ~ 1.30% done
# Processed tweet #95600 on 7334404 ~ 1.30% done
# Processed tweet #95700 on 7334404 ~ 1.30% done
# Processed tweet #95800 on 7334404 ~ 1.31% done
# Processed tweet #95900 on 7334404 ~ 1.31% done
# Processed tweet #96000 on 7334404 ~ 1.31% done
# Processed tweet #96100 on 7334404 ~ 1.31% done
# Processed tweet #96200 on 7334404 ~ 1.31% done
# Processed tweet #96300 on 7334404 ~ 1.31% done
# Processed tweet #96400 on 7334404 ~ 1.31% done
# Processed tweet #96500 on 7334404 ~ 1.32% done
# Processed tweet #96600 on 7334404 ~ 1.32% done
# Processed tweet #96700 on 7334404 ~ 1.32% done
# Processed tweet #96800 on 7334404 ~ 1.32% done
# Processed tweet #96900 on 7334404 ~ 1.32% done
# Processed tweet #97000 on 7334404 ~ 1.32% done
# Processed tweet #97100 on 7334404 ~ 1.32% done
# Processed tweet #97200 on 7334404 ~ 1.33% done
# Processed tweet #97300 on 7334404 ~ 1.33% done
# Processed tweet #97400 on 7334404 ~ 1.33% done
# Processed tweet #97500 on 7334404 ~ 1.33% done
# Processed tweet #97600 on 7334404 ~ 1.33% done
# Processed tweet #97700 on 7334404 ~ 1.33% done
# Processed tweet #97800 on 7334404 ~ 1.33% done
# Processed tweet #97900 on 7334404 ~ 1.33% done
# Processed tweet #98000 on 7334404 ~ 1.34% done
# Processed tweet #98100 on 7334404 ~ 1.34% done
# Processed tweet #98200 on 7334404 ~ 1.34% done
# Processed tweet #98300 on 7334404 ~ 1.34% done
# Processed tweet #98400 on 7334404 ~ 1.34% done
# Processed tweet #98500 on 7334404 ~ 1.34% done
# Processed tweet #98600 on 7334404 ~ 1.34% done
# Processed tweet #98700 on 7334404 ~ 1.35% done
# Processed tweet #98800 on 7334404 ~ 1.35% done
# Processed tweet #98900 on 7334404 ~ 1.35% done
# Processed tweet #99000 on 7334404 ~ 1.35% done
# Processed tweet #99100 on 7334404 ~ 1.35% done
# Processed tweet #99200 on 7334404 ~ 1.35% done
# Processed tweet #99300 on 7334404 ~ 1.35% done
# Processed tweet #99400 on 7334404 ~ 1.36% done
# Processed tweet #99500 on 7334404 ~ 1.36% done
# Processed tweet #99600 on 7334404 ~ 1.36% done
# Processed tweet #99700 on 7334404 ~ 1.36% done
# Processed tweet #99800 on 7334404 ~ 1.36% done
# Processed tweet #99900 on 7334404 ~ 1.36% done
# Processed tweet #100000 on 7334404 ~ 1.36% done
# Processed tweet #100100 on 7334404 ~ 1.36% done
# Processed tweet #100200 on 7334404 ~ 1.37% done
# ...
# Processed tweet #134800 on 7334404 ~ 1.84% done
# Processed tweet #134900 on 7334404 ~ 1.84% done
# Processed tweet #135000 on 7334404 ~ 1.84% done
# Processed tweet #135100 on 7334404 ~ 1.84% done
# Processed tweet #135200 on 7334404 ~ 1.84% done
# Processed tweet #135300 on 7334404 ~ 1.84% done
# Processed tweet #135400 on 7334404 ~ 1.85% done
# Processed tweet #135500 on 7334404 ~ 1.85% done
# Processed tweet #135600 on 7334404 ~ 1.85% done
# Processed tweet #135700 on 7334404 ~ 1.85% done
# Processed tweet #135800 on 7334404 ~ 1.85% done
# Processed tweet #135900 on 7334404 ~ 1.85% done
# Processed tweet #136000 on 7334404 ~ 1.85% done
# Processed tweet #136100 on 7334404 ~ 1.86% done
# Processed tweet #136200 on 7334404 ~ 1.86% done
# Processed tweet #136300 on 7334404 ~ 1.86% done
# Processed tweet #136400 on 7334404 ~ 1.86% done
# Processed tweet #136500 on 7334404 ~ 1.86% done
# Processed tweet #136600 on 7334404 ~ 1.86% done
# Processed tweet #136700 on 7334404 ~ 1.86% done
# Processed tweet #136800 on 7334404 ~ 1.87% done
# Processed tweet #136900 on 7334404 ~ 1.87% done
# Processed tweet #137000 on 7334404 ~ 1.87% done
# Processed tweet #137100 on 7334404 ~ 1.87% done
# Processed tweet #137200 on 7334404 ~ 1.87% done
# Processed tweet #137300 on 7334404 ~ 1.87% done
# Processed tweet #137400 on 7334404 ~ 1.87% done
# Processed tweet #137500 on 7334404 ~ 1.87% done
# Processed tweet #137600 on 7334404 ~ 1.88% done
# Processed tweet #137700 on 7334404 ~ 1.88% done
# Processed tweet #137800 on 7334404 ~ 1.88% done
# Processed tweet #137900 on 7334404 ~ 1.88% done
# Processed tweet #138000 on 7334404 ~ 1.88% done
# Processed tweet #138100 on 7334404 ~ 1.88% done
# Processed tweet #138200 on 7334404 ~ 1.88% done
# Processed tweet #138300 on 7334404 ~ 1.89% done
# Processed tweet #138400 on 7334404 ~ 1.89% done
# Processed tweet #138500 on 7334404 ~ 1.89% done
# Processed tweet #138600 on 7334404 ~ 1.89% done
# Processed tweet #138700 on 7334404 ~ 1.89% done
# Processed tweet #138800 on 7334404 ~ 1.89% done
# Processed tweet #138900 on 7334404 ~ 1.89% done
# Processed tweet #139000 on 7334404 ~ 1.90% done
# Processed tweet #139100 on 7334404 ~ 1.90% done
# Processed tweet #139200 on 7334404 ~ 1.90% done
# Processed tweet #139300 on 7334404 ~ 1.90% done
# Processed tweet #139400 on 7334404 ~ 1.90% done
# Processed tweet #139500 on 7334404 ~ 1.90% done
# Processed tweet #139600 on 7334404 ~ 1.90% done
# Processed tweet #139700 on 7334404 ~ 1.90% done
# Processed tweet #139800 on 7334404 ~ 1.91% done
# Processed tweet #139900 on 7334404 ~ 1.91% done
# Processed tweet #140000 on 7334404 ~ 1.91% done
# Processed tweet #140100 on 7334404 ~ 1.91% done
# Processed tweet #140200 on 7334404 ~ 1.91% done
# Processed tweet #140300 on 7334404 ~ 1.91% done
# Processed tweet #140400 on 7334404 ~ 1.91% done
# Processed tweet #140500 on 7334404 ~ 1.92% done
# Processed tweet #140600 on 7334404 ~ 1.92% done
# Processed tweet #140700 on 7334404 ~ 1.92% done
# Processed tweet #140800 on 7334404 ~ 1.92% done
# Processed tweet #140900 on 7334404 ~ 1.92% done
# Processed tweet #141000 on 7334404 ~ 1.92% done
# Processed tweet #141100 on 7334404 ~ 1.92% done
# Processed tweet #141200 on 7334404 ~ 1.93% done
# Processed tweet #141300 on 7334404 ~ 1.93% done
# Processed tweet #141400 on 7334404 ~ 1.93% done
# Processed tweet #141500 on 7334404 ~ 1.93% done
# Processed tweet #141600 on 7334404 ~ 1.93% done
# Processed tweet #141700 on 7334404 ~ 1.93% done
# Processed tweet #141800 on 7334404 ~ 1.93% done
# Processed tweet #141900 on 7334404 ~ 1.93% done
# Processed tweet #142000 on 7334404 ~ 1.94% done
# Processed tweet #153700 on 7334404 ~ 2.10% done
# Processed tweet #153800 on 7334404 ~ 2.10% done
# Processed tweet #153900 on 7334404 ~ 2.10% done
# Processed tweet #154000 on 7334404 ~ 2.10% done
# Processed tweet #154100 on 7334404 ~ 2.10% done
# Processed tweet #154200 on 7334404 ~ 2.10% done
# Processed tweet #154300 on 7334404 ~ 2.10% done
# Processed tweet #154400 on 7334404 ~ 2.11% done
# Processed tweet #154500 on 7334404 ~ 2.11% done
# Processed tweet #154600 on 7334404 ~ 2.11% done
# Processed tweet #154700 on 7334404 ~ 2.11% done
# Processed tweet #154800 on 7334404 ~ 2.11% done
# Processed tweet #154900 on 7334404 ~ 2.11% done
# Processed tweet #155000 on 7334404 ~ 2.11% done
# Processed tweet #155100 on 7334404 ~ 2.11% done
# Processed tweet #155200 on 7334404 ~ 2.12% done
# Processed tweet #155300 on 7334404 ~ 2.12% done
# Processed tweet #155400 on 7334404 ~ 2.12% done
# Processed tweet #155500 on 7334404 ~ 2.12% done
# Processed tweet #155600 on 7334404 ~ 2.12% done
# Processed tweet #155700 on 7334404 ~ 2.12% done
# Processed tweet #155800 on 7334404 ~ 2.12% done
# Processed tweet #155900 on 7334404 ~ 2.13% done
# Processed tweet #156000 on 7334404 ~ 2.13% done
# Processed tweet #156100 on 7334404 ~ 2.13% done
# Processed tweet #156200 on 7334404 ~ 2.13% done
# Processed tweet #156300 on 7334404 ~ 2.13% done
# Processed tweet #156400 on 7334404 ~ 2.13% done
# Processed tweet #156500 on 7334404 ~ 2.13% done
# Processed tweet #156600 on 7334404 ~ 2.14% done
# Processed tweet #156700 on 7334404 ~ 2.14% done
# Processed tweet #156800 on 7334404 ~ 2.14% done
# Processed tweet #156900 on 7334404 ~ 2.14% done
# Processed tweet #157000 on 7334404 ~ 2.14% done
# Processed tweet #157100 on 7334404 ~ 2.14% done
# Processed tweet #157200 on 7334404 ~ 2.14% done
# Processed tweet #157300 on 7334404 ~ 2.14% done
# Processed tweet #157400 on 7334404 ~ 2.15% done
# Processed tweet #157500 on 7334404 ~ 2.15% done
# Processed tweet #157600 on 7334404 ~ 2.15% done
# Processed tweet #157700 on 7334404 ~ 2.15% done
# Processed tweet #157800 on 7334404 ~ 2.15% done
# Processed tweet #157900 on 7334404 ~ 2.15% done
# Processed tweet #158000 on 7334404 ~ 2.15% done
# Processed tweet #158100 on 7334404 ~ 2.16% done
# Processed tweet #158200 on 7334404 ~ 2.16% done
# Processed tweet #158300 on 7334404 ~ 2.16% done
# Processed tweet #158400 on 7334404 ~ 2.16% done
# Processed tweet #158500 on 7334404 ~ 2.16% done
# ---------------------------------------------------------------------------
# CursorNotFound                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 count = 0
# ----> 2 for t in tweetsToProcess :
#       3     if count > 146490 :
#       4         await process_user_popularity(t)
#
# File ~/.conda/envs/kodjo/lib/python3.8/site-packages/pymongo/cursor.py:1238, in Cursor.next(self)
#    1236 if self.__empty:
#    1237     raise StopIteration
# -> 1238 if len(self.__data) or self._refresh():
#    1239     if self.__manipulate:
#    1240         _db = self.__collection.database
#
# File ~/.conda/envs/kodjo/lib/python3.8/site-packages/pymongo/cursor.py:1175, in Cursor._refresh(self)
#    1163     # Exhaust cursors don't send getMore messages.
#    1164     g = self._getmore_class(self.__dbname,
#    1165                             self.__collname,
#    1166                             limit,
#    (...)
#    1173                             self.__sock_mgr,
#    1174                             self.__exhaust)
# -> 1175     self.__send_message(g)
#    1177 return len(self.__data)
#
# File ~/.conda/envs/kodjo/lib/python3.8/site-packages/pymongo/cursor.py:1044, in Cursor.__send_message(self, operation)
#    1040     raise InvalidOperation(
#    1041         "exhaust cursors do not support auto encryption")
#    1043 try:
# -> 1044     response = client._run_operation(
#    1045         operation, self._unpack_response, address=self.__address)
#    1046 except OperationFailure as exc:
#    1047     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1048         # Don't send killCursors because the cursor is already closed.
#
# File ~/.conda/envs/kodjo/lib/python3.8/site-packages/pymongo/mongo_client.py:1424, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1419 def _cmd(session, server, sock_info, secondary_ok):
#    1420     return server.run_operation(
#    1421         sock_info, operation, secondary_ok, self._event_listeners,
#    1422         unpack_res)
# -> 1424 return self._retryable_read(
#    1425     _cmd, operation.read_preference, operation.session,
#    1426     address=address, retryable=isinstance(operation, message._Query))
#
# File ~/.conda/envs/kodjo/lib/python3.8/site-packages/pymongo/mongo_client.py:1525, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1521         if retrying and not retryable:
#    1522             # A retry is not possible because this server does
#    1523             # not support retryable reads, raise the last error.
#    1524             raise last_error
# -> 1525         return func(session, server, sock_info, secondary_ok)
#    1526 except ServerSelectionTimeoutError:
#    1527     if retrying:
#    1528         # The application may think the write was never attempted
#    1529         # if we raise ServerSelectionTimeoutError on the retry
#    1530         # attempt. Raise the original exception instead.
#
# File ~/.conda/envs/kodjo/lib/python3.8/site-packages/pymongo/mongo_client.py:1420, in MongoClient._run_operation.<locals>._cmd(session, server, sock_info, secondary_ok)
#    1419 def _cmd(session, server, sock_info, secondary_ok):
# -> 1420     return server.run_operation(
#    1421         sock_info, operation, secondary_ok, self._event_listeners,
#    1422         unpack_res)
#
# File ~/.conda/envs/kodjo/lib/python3.8/site-packages/pymongo/server.py:130, in Server.run_operation(self, sock_info, operation, set_secondary_okay, listeners, unpack_res)
#     128         first = docs[0]
#     129         operation.client._process_response(first, operation.session)
# --> 130         _check_command_response(first, sock_info.max_wire_version)
#     131 except Exception as exc:
#     132     if publish:
#
# File ~/.conda/envs/kodjo/lib/python3.8/site-packages/pymongo/helpers.py:165, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     163     raise ExecutionTimeout(errmsg, code, response, max_wire_version)
#     164 elif code == 43:
# --> 165     raise CursorNotFound(errmsg, code, response, max_wire_version)
#     167 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# CursorNotFound: cursor id 3281865858233297188 not found, full error: {'ok': 0.0, 'errmsg': 'cursor id 3281865858233297188 not found', 'code': 43, 'codeName': 'CursorNotFound'}

# %%
count
# Out:
# 158592
